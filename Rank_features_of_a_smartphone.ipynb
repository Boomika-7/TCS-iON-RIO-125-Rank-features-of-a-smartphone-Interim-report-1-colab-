# %%
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset1=pd.read_csv('MobileTest.csv')
dataset1
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
ds=pd.read_csv('MobileTrain.csv')
ds
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
ds.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
ds.shape
# Out:
# (2000, 21)

# %%
type(ds)
# Out:
# pandas.core.frame.DataFrame

# %%
ds.size
# Out:
# 42000

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
ds.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
print(ds.isnull())
print(ds.isnull().sum())
# Out:
#       battery_power   blue  clock_speed  dual_sim     fc  four_g  int_memory  \
# 0             False  False        False     False  False   False       False
# 1             False  False        False     False  False   False       False
# 2             False  False        False     False  False   False       False
# 3             False  False        False     False  False   False       False
# 4             False  False        False     False  False   False       False
# ...             ...    ...          ...       ...    ...     ...         ...
# 1995          False  False        False     False  False   False       False
# 1996          False  False        False     False  False   False       False
# 1997          False  False        False     False  False   False       False
# 1998          False  False        False     False  False   False       False
# 1999          False  False        False     False  False   False       False
#
# ...

# %% [markdown]
# ***HISTOGRAM***

# %%
ds["Is_blue"]=''
for i in range(len(ds)):
  if ds["blue"][i]==0:
    ds.loc[i,"Is_blue"]="No"
  else:
    ds.loc[i,"Is_blue"]="Yes"
ds
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
px.histogram(data_frame=ds,x="Is_blue",color="price_range",title="Comparision of devices sold having blue color")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ds["Is_wifi"]=""
for i in range(len(ds)):
  if ds["wifi"][i]==0:
    ds.loc[i,"Is_wifi"]="No"
  else:
    ds.loc[i,"Is_wifi"]="Yes"
ds
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# ...

# %%
px.histogram(data_frame=ds,x="Is_wifi",color="price_range",title="Comparision of devices sold having wifi or not")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ds["Is_touch_screen"]=''
for i in range(len(ds)):
  if ds["touch_screen"][i]==0:
    ds.loc[i,"Is_touch_screen"]="No"
  else:
    ds.loc[i,"Is_touch_screen"]="Yes"
ds
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  sc_h  sc_w  talk_time  three_g  \
# ...

# %%
px.histogram(data_frame=ds,x="Is_touch_screen",color="price_range",title="Comparision of devices sold having touch screen or not")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ds["Is_four_g"]=''
for i in range(len(ds)):
  if ds["four_g"][i]==0:
    ds.loc[i,"Is_four_g"]="No"
  else:
    ds.loc[i,"Is_four_g"]="Yes"
ds
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  sc_w  talk_time  three_g  touch_screen  \
# ...

# %%
px.histogram(data_frame=ds,x="Is_four_g",color="price_range",title="Comparision of devices sold having 4G or not")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ***PIE CHART***

# %%
px.pie(data_frame=ds,names="Is_blue",title="Percentage of devices having bluetooth",hole=0.1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(data_frame=ds,names="Is_wifi",title="Percentage of devices having wifi",hole=0.1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(data_frame=ds,names="Is_touch_screen",title="Percentage of devices having touch screen",hole=0.1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(data_frame=ds,names="Is_four_g",title="Percentage of devices having 4G",hole=0.1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ds["Is_dual_sim"]=''
for i in range(len(ds)):
  if(ds["dual_sim"][i]==0):
    ds.loc[i,"Is_dual_sim"]="No"
  else:
    ds.loc[i,"Is_dual_sim"]="Yes"
px.pie(data_frame=ds,names="Is_dual_sim",hole=0.1,title="Percentage of devices having dual sim")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ds["Is_three_g"]=''
for i in range(len(ds)):
  if(ds["three_g"][i]==0):
    ds.loc[i,"Is_three_g"]="No"
  else:
    ds.loc[i,"Is_three_g"]="Yes"
px.pie(data_frame=ds,names="Is_three_g",hole=0.1,title="Percentage of devices having 3G")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ds["cores"]=''
for i in range(len(ds)):
  if(ds["n_cores"][i]==1):
    ds.loc[i,"cores"]="Single core"
  elif(ds["n_cores"][i]==2):
    ds.loc[i,"cores"]="Dual core"
  elif(ds["n_cores"][i]==3):
    ds.loc[i,"cores"]="Triple core"
  elif(ds["n_cores"][i]==4):
    ds.loc[i,"cores"]="Quad core"
  elif(ds["n_cores"][i]==5):
    ds.loc[i,"cores"]="Penta core"
  elif(ds["n_cores"][i]==6):
    ds.loc[i,"cores"]="Hexa core"
  elif(ds["n_cores"][i]==7):
    ds.loc[i,"cores"]="Hepta core"
  else:
    ds.loc[i,"cores"]="Octal core"
px.pie(data_frame=ds,names="cores",hole=0.1,title="Percentage of devices having different types of cores")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ***COUNT*** ***PLOT***

# %%
for i in ds:
  if(ds[i].nunique()<30):
    sns.countplot(x=ds[i])
    plt.show()

# %% [markdown]
# ***DIST*** ***PLOT***

# %%
sns.displot(ds['battery_power'])
plt.show()

sns.displot(ds['clock_speed'])
plt.show()

sns.displot(ds['int_memory'])
plt.show()

sns.displot(ds['m_dep'])
plt.show()

sns.displot(ds['mobile_wt'])
plt.show()

sns.displot(ds['px_height'])
plt.show()

sns.displot(ds['px_width'])
plt.show()

sns.displot(ds['ram'])
plt.show()

sns.displot(ds['talk_time'])
plt.show()

# %% [markdown]
# ***CLASSIFICATION ALGORITHM***

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ds=pd.read_csv('MobileTrain.csv')

# %%
x = ds.iloc[:, :-1].values
y = ds.iloc[:, -1].values
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x = sc_x.fit_transform(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state=0)

# %% [markdown]
# ***LOGISTIC REGRESSION***

# %%
log=LogisticRegression(max_iter=5000)
log.fit(x_train,y_train)
print("score {}".format(log.score(x_train,y_train)*100))
pred_log=log.predict(x_test)
print(pred_log)
acrr=accuracy_score(y_test,pred_log)*100
print("Accuracy Score {}%".format(acrr))
print("Confusion matrix {}".format(confusion_matrix(y_test,pred_log)))
print("{}".format(classification_report(y_test,pred_log)))
# Out:
# score 97.93333333333332
# [3 0 2 2 3 0 0 3 3 1 1 3 0 2 3 0 3 2 2 1 0 0 3 1 2 2 3 1 3 1 1 0 2 0 1 3 0
#  0 3 3 3 1 3 3 1 3 0 1 3 1 1 3 0 3 0 2 2 2 0 3 3 1 3 2 1 2 3 2 2 2 3 2 1 0
#  1 3 2 2 1 2 3 3 3 0 0 0 2 1 2 3 1 2 2 1 0 3 3 3 0 3 1 1 2 1 3 2 2 3 2 3 3
#  0 0 1 3 3 0 0 1 0 0 3 2 2 1 2 1 1 0 2 1 3 3 3 3 3 3 2 0 1 1 2 1 3 0 3 0 0
#  2 0 1 1 1 1 3 0 0 3 1 3 2 1 3 1 2 3 3 2 1 0 3 1 2 3 3 0 2 2 3 1 2 1 0 1 2
#  1 2 0 3 3 1 1 0 2 3 0 1 2 2 0 3 3 3 1 2 3 3 3 0 0 0 2 3 3 0 0 1 3 2 3 3 3
#  0 0 2 3 3 1 0 2 0 0 0 3 2 1 2 2 1 1 0 2 3 3 0 0 1 3 3 1 3 0 3 1 1 0 2 3 3
#  2 0 0 1 2 3 2 2 3 1 1 0 3 3 2 1 3 2 2 2 1 0 2 2 1 0 0 2 2 2 3 0 1 3 0 2 2
#  3 0 2 0 1 1 3 0 0 2 3 1 2 0 2 0 3 0 3 3 2 3 1 2 2 1 1 2 0 1 0 3 1 0 3 0 0
#  1 3 0 3 1 1 0 1 3 0 2 1 1 2 1 1 0 2 0 0 3 1 2 3 2 2 0 3 2 2 1 3 2 3 3 3 0
#  2 0 3 0 1 1 2 3 1 3 1 2 0 1 2 3 0 0 1 3 0 3 0 2 2 1 1 0 2 0 0 1 3 0 3 3 0
#  2 1 3 1 1 3 2 0 3 2 2 0 0 3 0 1 1 1 3 2 3 2 0 3 0 0 1 3 0 0 3 2 2 2 3 0 0
# ...

# %% [markdown]
# ***SVM***

# %%
svm=SVC(kernel='rbf')
svm.fit(x_train,y_train)
print("Training score of SVM is: {}".format(svm.score(x_train,y_train)*100))
y_pred_svm=svm.predict(x_test)
ac_svm=accuracy_score(y_test,y_pred_svm)*100
print("Accuracy of SVM is: {}".format(ac_svm))
print("Confusion matrix of SVM is: {}".format(confusion_matrix(y_test,y_pred_svm)))
print("{}".format(classification_report(y_test,y_pred_svm)))
# Out:
# Training score of SVM is: 98.06666666666666
# Accuracy of SVM is: 89.0
# Confusion matrix of SVM is: [[118   6   0   0]
#  [  6  96   8   0]
#  [  0  15 106   4]
#  [  0   0  16 125]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       124
#            1       0.82      0.87      0.85       110
#            2       0.82      0.85      0.83       125
#            3       0.97      0.89      0.93       141
#
#     accuracy                           0.89       500
#    macro avg       0.89      0.89      0.89       500
# weighted avg       0.89      0.89      0.89       500

# %% [markdown]
# ***NAIVE BAYES***

# %%
nb=GaussianNB()
nb.fit(x_train,y_train)
print("Training score of GaussianNB is {}".format(nb.score(x_train,y_train)*100))
y_pred=nb.predict(x_test)
ac_nb=accuracy_score(y_test,y_pred)*100
print("Accuracy of Naive Bayes Classifier is: {}".format(ac_nb))
print("Confusion matrix of Naive Bayes Classifier is:{}".format(confusion_matrix(y_test,y_pred)))
print("{}".format(classification_report(y_test,y_pred)))
# Out:
# Training score of GaussianNB is 81.39999999999999
# Accuracy of Naive Bayes Classifier is: 84.39999999999999
# Confusion matrix of Naive Bayes Classifier is:[[117   7   0   0]
#  [  6  83  21   0]
#  [  0  22  92  11]
#  [  0   0  11 130]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       124
#            1       0.74      0.75      0.75       110
#            2       0.74      0.74      0.74       125
#            3       0.92      0.92      0.92       141
#
#     accuracy                           0.84       500
#    macro avg       0.84      0.84      0.84       500
# weighted avg       0.84      0.84      0.84       500

# %% [markdown]
# ***DESICION TREE***

# %%
DT=DecisionTreeClassifier(criterion = "entropy")
DT.fit(x_train,y_train)
print("Training score of DecisionTreeClassifier is: {}".format(DT.score(x_train,y_train)*100))
y_pred_DT=DT.predict(x_test)
ac_DT=accuracy_score(y_test,y_pred_DT)*100
print("Accuracy of Decision Tree Classifier is: {}".format(ac_DT))
print("Confusion matrix of Decision Tree Classifier is: {}".format(confusion_matrix(y_test,y_pred_DT)))
print("{}".format(classification_report(y_test,y_pred_DT)))
# Out:
# Training score of DecisionTreeClassifier is: 100.0
# Accuracy of Decision Tree Classifier is: 84.6
# Confusion matrix of Decision Tree Classifier is: [[114  10   0   0]
#  [ 10  90  10   0]
#  [  0  12  99  14]
#  [  0   0  21 120]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       124
#            1       0.80      0.82      0.81       110
#            2       0.76      0.79      0.78       125
#            3       0.90      0.85      0.87       141
#
#     accuracy                           0.85       500
#    macro avg       0.84      0.85      0.84       500
# weighted avg       0.85      0.85      0.85       500

# %% [markdown]
# ***RANDOM FOREST CLASSIFIER***

# %%
RF=RandomForestClassifier(n_estimators=300)
RF.fit(x_train,y_train)
print("Training score of Random Forest Classifier is: {}".format(RF.score(x_train,y_train)*100))
y_pred_RF=RF.predict(x_test)
ac_RF=accuracy_score(y_test,y_pred_RF)*100
print("Accuracy of Random Forest Classifier is: {}".format(ac_RF))
print("Confusion matrix of Random Forest Classifier is: {}".format(confusion_matrix(y_test,y_pred_RF)))
print("{}".format(classification_report(y_test,y_pred_RF)))
# Out:
# Training score of Random Forest Classifier is: 100.0
# Accuracy of Random Forest Classifier is: 87.2
# Confusion matrix of Random Forest Classifier is: [[122   2   0   0]
#  [  8  90  12   0]
#  [  0  19  95  11]
#  [  0   0  12 129]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       124
#            1       0.81      0.82      0.81       110
#            2       0.80      0.76      0.78       125
#            3       0.92      0.91      0.92       141
#
#     accuracy                           0.87       500
#    macro avg       0.87      0.87      0.87       500
# weighted avg       0.87      0.87      0.87       500

# %% [markdown]
# ***COMPARISON OF CLASSIFIER***

# %%
classifiers=["LogisticRegression","GaussianNB","SVM","DecisionTreeClassifier","RandomForestClassifier"]
accuracy_=[acrr,ac_nb,ac_svm,ac_DT,ac_RF]
df_ac=pd.DataFrame({'model':classifiers,"accuracy":accuracy_})
px.histogram(data_frame=df_ac,x="model",y="accuracy")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
